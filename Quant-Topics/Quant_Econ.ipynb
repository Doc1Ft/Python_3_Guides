# %%
#import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager
# %matplotlib inline
import datetime as dt
import sympy

# %%
#numerical programming
a = np.linspace(-np.pi, np.pi, 100)
b = np.cos(a)
c = np.sin(a)

# %%
b @ c
# Out:
# 4.04891256782214e-16

# %%
#scientific programming
from scipy.stats import norm
from scipy.integrate import quad

var1 = norm()
value, error = quad(var1.pdf, -2,2) #integrate using Gaussian quadrature
value
# Out:
# 0.9544997361036417

# %%
from sympy import Symbol

x,y = Symbol('x'),Symbol('y') #treat 'x' and 'y' as algebraic symbols

x + x + x + y
# Out:
# 3*x + y

# %%
expression = (x+y)**2
expression.expand()
# Out:
# x**2 + 2*x*y + y**2

# %%
from sympy import solve

solve(x**2 + x + 2)
# Out:
# [-1/2 - sqrt(7)*I/2, -1/2 + sqrt(7)*I/2]

# %%
from sympy import limit, sin, diff

limit(1/ x, x, 0)
# Out:
# oo

# %%
limit(sin(x) / x, x, 0)
# Out:
# 1

# %%
diff(sin(x), x)
# Out:
# cos(x)

# %%
#statistics
np.random.seed(1234)

data = np.random.randn(5, 2) #5x2 matrix of N(0, 1) random draws
dates = pd.date_range('09/20/2019', periods=5)

df = pd.DataFrame(data, columns=('price','weight'), index=dates)
df
# Out:
#                price    weight
# 2019-09-20  0.471435 -1.190976
# 2019-09-21  1.432707 -0.312652
# 2019-09-22 -0.720589  0.887163
# 2019-09-23  0.859588 -0.636524
# 2019-09-24  0.015696 -2.242685

# %%
df.mean()
# Out:
# price     0.411768
# weight   -0.699135
# dtype: float64

# %%
import networkx as nx

np.random.seed(1234)

#generate a random graph
p = dict((i, (np.random.uniform(0, 1), np.random.uniform(0, 1)))
         for i in range(200))
g = nx.random_geometric_graph(200, 0.12, pos=p)
pos = nx.get_node_attributes(g, 'pos')

#find node nearest the center point (0.5,0.5)
dists = [(x - 0.5)**2 + (y - 0.5)**2 for x, y in list(pos.values())]
ncenter = np.argmin(dists)

#plot graph, coloring by path length from central node

# %%
p = nx.single_source_shortest_path_length(g, ncenter)
plt.figure()
nx.draw_networkx_edges(g, pos, alpha=0.4)
nx.draw_networkx_nodes(g,
                     pos,
                     nodelist=list(p.keys()),
                     node_size=120, alpha=0.5,
                     node_color=list(p.values()),
                     cmap=plt.cm.jet_r)
plt.show()
# Out:
# C:\Users\t627752\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
N = 20
θ = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, polar=True)
bars = ax.bar(θ, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r / 10.))
    bar.set_alpha(0.5)
plt.show()

# %%
#use numpy to create random numbers
np.random.randn(3)
# Out:
# array([-0.42782611,  1.49856996, -0.36015657])

# %%
#use ? to get help
np.rank?

# %%
#show path
pwd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-54905aa8a210> in <module>
#       1 #show path
# ----> 2 pwd
#
# NameError: name 'pwd' is not defined

# %%
#view directory
ls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9da8c15f7084> in <module>
#       1 #view directory
# ----> 2 ls
#
# NameError: name 'ls' is not defined

# %%
#numpy basics, reinforced
x = np.random.randn(100)
plt.plot(x)
plt.show()

# %%
np.sqrt(4)
# Out:
# 2.0

# %%
#alternative using a for loop
ts_length = 100
values = [] #empty list

for i in range(ts_length):
    e = np.random.randn()
    values.append(e)
    
plt.plot(values)
plt.show()

# %%
animals = ['dog','cat','snake']
plural = [i + 's' for i in animals]
plural
# Out:
# ['dogs', 'cats', 'snakes']

# %%
#3.6 Exercise 1 - create a function factorial
def factorial(x):
    k = 1
    for i in range(x):
        k = k * (i+1)
    return k
factorial(4)
# Out:
# 24

# %%
#page 57 continue..
